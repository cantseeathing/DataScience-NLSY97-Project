# %% [markdown]
# # Introduction

# %% [markdown]
# The National Longitudinal Survey of Youth 1997-2011 dataset is one of the most important databases available to social scientists working with US data.
#
# It allows scientists to look at the determinants of earnings as well as educational attainment and has incredible relevance for government policy. It can also shed light on politically sensitive issues like how different educational attainment and salaries are for people of different ethnicity, sex, and other factors. When we have a better understanding how these variables affect education and earnings we can also formulate more suitable government policies.
#
# <center><img src=https://i.imgur.com/cxBpQ3I.png height=400></center>

# %% [markdown]
# ### Upgrade Plotly

# %%
# %pip install --upgrade plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ###  Import Statements

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
np.random.seed(1)

# %% [markdown]
# ## Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Load the Data

# %%
df_data = pd.read_csv('NLSY97_subset.csv')

# %% [markdown]
# ### Understand the Dataset
#
# Have a look at the file entitled `NLSY97_Variable_Names_and_Descriptions.csv`.
#
# ---------------------------
#
#     :Key Variables:
#       1. S           Years of schooling (highest grade completed as of 2011)
#       2. EXP         Total out-of-school work experience (years) as of the 2011 interview.
#       3. EARNINGS    Current hourly earnings in $ reported at the 2011 interview

# %% [markdown]
# # Preliminary Data Exploration 🔎
#
# **Challenge**
#
# * What is the shape of `df_data`?
# * How many rows and columns does it have?
# * What are the column names?
# * Are there any NaN values or duplicates?

# %%
df_data = df_data[['S', 'EXP', 'EARNINGS']]

# %%
df_data.shape
# Out:
# (2000, 3)

# %%
df_data.head()
# Out:
#     S  EXP  EARNINGS
# 0  12 9.71     18.50
# 1  17 5.71     19.23
# 2  14 9.94     39.05
# 3  18 1.54     16.80
# 4  15 2.94     36.06

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   S         2000 non-null   int64
#  1   EXP       2000 non-null   float64
#  2   EARNINGS  2000 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 47.0 KB

# %%
df_data.isna().any().sum()
# Out:
# 0

# %%
df_data.columns[df_data.isna().any()]
# Out:
# Index([], dtype='object')

# %%
df_data[df_data.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [S, EXP, EARNINGS]
# Index: []

# %%
df_data.duplicated().any()
# Out:
# True

# %% [markdown]
# ## Data Cleaning - Check for Missing Values and Duplicates
#
# Find and remove any duplicate rows.

# %%
df_data.drop_duplicates(inplace=True)

# %%
df_data.shape
# Out:
# (1486, 3)

# %%
df_data.duplicated().any()
# Out:
# False

# %%
df_data.isna().any().sum()
# Out:
# 0

# %%
df_data.head()
# Out:
#     S  EXP  EARNINGS
# 0  12 9.71     18.50
# 1  17 5.71     19.23
# 2  14 9.94     39.05
# 3  18 1.54     16.80
# 4  15 2.94     36.06

# %%
# df_data = df_data.drop(df_data.columns[df_data.isna().any()], axis=1)

# %%
df_data.isna().any().sum()
# Out:
# 0

# %% [markdown]
# ## Descriptive Statistics

# %%
df_data.describe()
# Out:
#              S      EXP  EARNINGS
# count 1,486.00 1,486.00  1,486.00
# mean     14.56     6.70     18.81
# std       2.77     2.86     12.00
# min       6.00     0.00      2.00
# 25%      12.00     4.66     11.41
# 50%      15.00     6.63     15.75
# 75%      16.00     8.71     22.60
# max      20.00    14.73    132.89

# %% [markdown]
# ## Visualise the Features

# %%
for col in df_data.drop('EARNINGS', axis=1).columns:
    plt.figure(figsize=(8,4), dpi=200)

    # set styling on a single chart
    with sns.axes_style('darkgrid'):
      ax = sns.scatterplot(data=df_data,
                           x='EARNINGS', 
                           y=f'{col}',
                           hue='EARNINGS',
                           size='EARNINGS')

      ax.set(ylabel=f'{col}',
            xlabel='EARNINGS')
    plt.show()

# %%
for col in df_data.drop('EARNINGS', axis=1).columns:
    with sns.axes_style('whitegrid'):
      sns.jointplot(x=df_data[f'{col}'], 
                    y=df_data.EARNINGS, 
                    height=7, 
                    color='darkblue',
                    joint_kws={'alpha':0.5})
    plt.show()

# %%
sns.displot(df_data['EARNINGS'], 
            bins=50, 
            aspect=2,
            kde=True, 
            color='#2196f3')

plt.title(f'Avg Earnings. Average: ${df_data.EARNINGS.mean():.02f}')
plt.xlabel('Earnings in $')
plt.ylabel('Nr. of Participants')

plt.show()

# %%
sns.displot(df_data['EXP'], 
            bins=50, 
            aspect=2,
            kde=True, 
            color='#2196f3')

plt.title(f'Avg out-of-school Experience. Average: ${df_data.EXP.mean():.02f}')
plt.xlabel('Years of out-of-school Experince')
plt.ylabel('Nr. of Participants')

plt.show()

# %%
sns.displot(df_data['S'], 
            bins=15, 
            aspect=2,
            kde=True, 
            color='#2196f3')

plt.title(f'Avg Years of Experience. Average: ${df_data.S.mean():.02f}')
plt.xlabel('Years of Experince')
plt.ylabel('Nr. of Participants')

plt.show()

# %% [markdown]
# # Split Training & Test Dataset
#
# We *can't* use all the entries in our dataset to train our model. Keep 20% of the data for later as a testing dataset (out-of-sample data).

# %%
X = df_data.drop(['EARNINGS'], axis=1)
y = df_data['EARNINGS']

# %%
X.head()
# Out:
#     S  EXP
# 0  12 9.71
# 1  17 5.71
# 2  14 9.94
# 3  18 1.54
# 4  15 2.94

# %%
y.head()
# Out:
# 0   18.50
# 1   19.23
# 2   39.05
# 3   16.80
# 4   36.06
# Name: EARNINGS, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Simple Linear Regression
#
# Only use the years of schooling to predict earnings. Use sklearn to run the regression on the training dataset. How high is the r-squared for the regression on the training data?

# %%
def evaluate_preds(y_true, y_preds):
    r2 = r2_score(y_true, y_preds)
    mae = mean_absolute_error(y_true, y_preds)
    mse = mean_squared_error(y_true, y_preds)
    metrics_dict = {'r2': round(r2, 2),
                    'MAE': round(mae, 2),
                    'MSE': round(mse, 2),
                    }
    return metrics_dict

# %%
df_data.head()
# Out:
#     S  EXP  EARNINGS
# 0  12 9.71     18.50
# 1  17 5.71     19.23
# 2  14 9.94     39.05
# 3  18 1.54     16.80
# 4  15 2.94     36.06

# %%
X = df_data[['S']]
y = df_data['EARNINGS']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
rsquared = reg.score(X_train, y_train)
print(f'Training data r-squared: {rsquared:.2}')
# Out:
# Training data r-squared: 0.087

# %%
evaluate_preds(y_test, y_pred)
# Out:
# {'r2': 0.05, 'MAE': 7.7, 'MSE': 148.72}

# %% [markdown]
# ### Evaluate the Coefficients of the Model
#
# Here we do a sense check on our regression coefficients. The first thing to look for is if the coefficients have the expected sign (positive or negative).
#
# Interpret the regression. How many extra dollars can one expect to earn for an additional year of schooling?

# %%
reg_coff = pd.DataFrame(data=reg.coef_, index=X_train.columns, columns=['Coefficient'])
reg_coff
# Out:
#    Coefficient
# S         1.28

# %%
premium = reg_coff.loc['S'].values[0]
print(f'The earnings premium for having an extra year is ${premium:0.2f}')
# Out:
# The earnings premium for having an extra year is $1.28

# %% [markdown]
# ### Analyse the Estimated Values & Regression Residuals
#
# How good our regression is also depends on the residuals - the difference between the model's predictions ( 𝑦̂ 𝑖 ) and the true values ( 𝑦𝑖 ) inside y_train. Do you see any patterns in the distribution of the residuals?

# %%
predicted_vals = reg.predict(X_train)
residuals = (y_train - predicted_vals)

# %%
# Original Regression of Actual vs. Predicted Prices
plt.figure(dpi=100)
plt.scatter(x=y_train, y=predicted_vals, c='indigo', alpha=0.6)
plt.plot(y_train, y_train, color='cyan')
plt.title(f'Actual vs Predicted Earnings: $y _i$ vs $\hat y_i$', fontsize=17)
plt.xlabel('Actual Earnings 000s $y _i$', fontsize=14)
plt.ylabel('Prediced Earnings 000s $\hat y _i$', fontsize=14)
plt.show()

# Residuals vs Predicted values
plt.figure(dpi=100)
plt.scatter(x=predicted_vals, y=residuals, c='indigo', alpha=0.6)
plt.title('Residuals vs Predicted Values', fontsize=17)
plt.xlabel('Predicted Earnings $\hat y _i$', fontsize=14)
plt.ylabel('Residuals', fontsize=14)
plt.show()

# %%
# Residual Distribution Chart
resid_mean = round(residuals.mean(), 2)
resid_skew = round(residuals.skew(), 2)

sns.displot(residuals, kde=True, color='indigo')
plt.title(f'Residuals Skew ({resid_skew}) Mean ({resid_mean})')
plt.show()

# %% [markdown]
# # Multivariable Regression
#
# Now use both years of schooling and the years work experience to predict earnings. How high is the r-squared for the regression on the training data?

# %%
df_data.head()
# Out:
#     S  EXP  EARNINGS
# 0  12 9.71     18.50
# 1  17 5.71     19.23
# 2  14 9.94     39.05
# 3  18 1.54     16.80
# 4  15 2.94     36.06

# %%
X = df_data[['S', 'EXP']]
y = df_data['EARNINGS']

# %%
X.head()
# Out:
#     S  EXP
# 0  12 9.71
# 1  17 5.71
# 2  14 9.94
# 3  18 1.54
# 4  15 2.94

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
rsquared = reg.score(X_train, y_train)
print(f'Training data r-squared: {rsquared:.2}')
# Out:
# Training data r-squared: 0.12

# %%
evaluate_preds(y_test, y_pred)
# Out:
# {'r2': 0.09, 'MAE': 7.52, 'MSE': 117.92}

# %% [markdown]
# ### Evaluate the Coefficients of the Model

# %%
reg_coff = pd.DataFrame(data=reg.coef_, index=X_train.columns, columns=['Coefficient'])
reg_coff
# Out:
#      Coefficient
# S           1.81
# EXP         0.99

# %% [markdown]
# ### Analyse the Estimated Values & Regression Residuals

# %%
predicted_vals = reg.predict(X_train)
residuals = (y_train - predicted_vals)

# %%
# Original Regression of Actual vs. Predicted Prices
plt.figure(dpi=100)
plt.scatter(x=y_train, y=predicted_vals, c='indigo', alpha=0.6)
plt.plot(y_train, y_train, color='cyan')
plt.title(f'Actual vs Predicted Earnings: $y _i$ vs $\hat y_i$', fontsize=17)
plt.xlabel('Actual Earnings 000s $y _i$', fontsize=14)
plt.ylabel('Prediced Earnings 000s $\hat y _i$', fontsize=14)
plt.show()

# Residuals vs Predicted values
plt.figure(dpi=100)
plt.scatter(x=predicted_vals, y=residuals, c='indigo', alpha=0.6)
plt.title('Residuals vs Predicted Values', fontsize=17)
plt.xlabel('Predicted Earnings $\hat y _i$', fontsize=14)
plt.ylabel('Residuals', fontsize=14)
plt.show()

# %%
# Residual Distribution Chart
resid_mean = round(residuals.mean(), 2)
resid_skew = round(residuals.skew(), 2)

sns.displot(residuals, kde=True, color='indigo')
plt.title(f'Residuals Skew ({resid_skew}) Mean ({resid_mean})')
plt.show()

# %% [markdown]
# # Use Your Model to Make a Prediction
#
# How much can someone with a bachelors degree (12 + 4) years of schooling and 5 years work experience expect to earn in 2011?

# %%
S = 14
EXP = 5
entry = pd.DataFrame(data=[(S, EXP)]).values

# %%
entry
# Out:
# array([[14,  5]], dtype=int64)

# %%
# Make prediction
estimate = reg.predict(entry)[0]
estimate
# Out:
# C:\Users\mahmo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 16.067575366507505

# %%
print(f'The earning estimate is ${estimate:.2f}')
# Out:
# The earning estimate is $16.07

# %% [markdown]
# # Experiment and Investigate Further
#
# Which other features could you consider adding to further improve the regression to better predict earnings?
